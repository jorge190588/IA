# %%
import tensorflow as tf
import time
from datetime import timedelta
import math
import random
import numpy as np
import conjuntoDeDatos
import os
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import glob
import cv2
import os
import glob
from sklearn.utils import shuffle
import numpy as np
import ConjuntoDeImagenes

#Prepare input data
classes = ['dog','cat']
num_classes = len(classes)
batch_size = 32
# 20% of the data will automatically be used for validation
validation_size = 0.2
img_size = 128
num_channels = 3
train_path=os.path.join(os.path.realpath('.'),'imagenes/train/')
print(train_path)
rutaDeDatosDeEntrenamiento=os.path.join(train_path,'dog'+'.*.jpg')
listaDeArchivos = glob.glob(rutaDeDatosDeEntrenamiento)
print(len(listaDeArchivos))
print(listaDeArchivos[0])

if os.path.isfile(listaDeArchivos[0]):
    imagen = cv2.imread(listaDeArchivos[0])
    imagen = cv2.cvtColor(imagen, cv2.COLOR_RGB2BGR)
    imagen = cv2.resize(imagen, (128, 128),0,0, cv2.INTER_LINEAR)
    imagen = imagen.astype(np.float64)
    imagen = np.multiply(imagen, 1.0 / 255.0)
    plt.imshow(imagen)
    plt.show()  

# We shall load all the training and validation images and labels into memory using openCV and use that during training
# data = dataset.read_train_sets(train_path, img_size, classes, validation_size=validation_size)
# data = conjuntoDeDatos.leerDatosDeEntrenamiento(train_path, img_size, classes,validation_size)
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /notebooks/CNNcatdogs/imagenes/train/
# 6891
# /notebooks/CNNcatdogs/imagenes/train/dog.11333.jpg

# %%
print("Complete reading input data. Will Now print a snippet of it")
print("Numero de imagenes en el conjunto de entrenamiento:\t{}".format(len(data.entrenamiento.etiquetas)))
print("Numero de imagenes en el conjunto de validacion :\t{}".format(len(data.validacion.etiquetas)))

trainImagenes =len(data.entrenamiento.imagenes)
print("train images "+ str(trainImagenes))

for index,imagen in enumerate(data.entrenamiento.imagenes[0:5]):
    print("etiqueta: "+str(data.entrenamiento.etiquetas[index]) + " Nombre: " +str(data.entrenamiento.nombres[index])+ "  clase: "+ data.entrenamiento.clases[index])
    plt.imshow(imagen)
    plt.show()
# Out:
# Complete reading input data. Will Now print a snippet of it
# Numero de imagenes en el conjunto de entrenamiento:	28
# Numero de imagenes en el conjunto de validacion :	6
# train images 28
# etiqueta: [0. 1.] Nombre: cat.11.jpg  clase: cat
# etiqueta: [1. 0.] Nombre: dog.9090.jpg  clase: dog
# etiqueta: [0. 1.] Nombre: cat.6.jpg  clase: cat
# etiqueta: [0. 1.] Nombre: cat.9911.jpg  clase: cat
# etiqueta: [1. 0.] Nombre: dog.9091.jpg  clase: dog
